# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# splitting and evaluation
from sklearn.model_selection import train_test_split, KFold, GridSearchCV, cross_val_score
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# preprocessing (removing missing values, scaling, encoding)
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder, StandardScaler

# models
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.preprocessing import FunctionTransformer

pd.set_option("display.float_format", "{:.0f}".format)

# %%
# so randomness can be reproduced
RANDOM_STATE = 42
np.random.seed(RANDOM_STATE)

# %%
adverts = pd.read_csv("adverts.csv")

# %%
# check data parsed correctly
adverts.head(5)
# Out:
#    public_reference  mileage reg_code standard_colour standard_make  \
# 0   202006039777689        0      NaN            Grey         Volvo
# 1   202007020778260   108230       61            Blue        Jaguar
# 2   202007020778474     7800       17            Grey         SKODA
# 3   202007080986776    45000       16           Brown      Vauxhall
# 4   202007161321269    64000       64            Grey    Land Rover
#
#       standard_model vehicle_condition  year_of_registration  price  \
# 0               XC90               NEW                   NaN  73970
# 1                 XF              USED                  2011   7000
# 2               Yeti              USED                  2017  14000
# 3              Mokka              USED                  2016   7995
# 4  Range Rover Sport              USED                  2015  26995
#
#    body_type  crossover_car_and_van              fuel_type
# 0        SUV                  False  Petrol Plug-in Hybrid
# 1     Saloon                  False                 Diesel
# 2        SUV                  False                 Petrol
# 3  Hatchback                  False                 Diesel
# 4        SUV                  False                 Diesel

# %%
adverts.shape
# Out:
# (402005, 12)

# %%
adverts.sample(5, random_state=RANDOM_STATE)
# Out:
#         public_reference  mileage reg_code standard_colour standard_make  \
# 332044   202010074692259     2826       69          Silver    Volkswagen
# 173955   202009023198786    10601       19             Red        Nissan
# 367464   202007221569681    23000       58          Silver         Honda
# 47695    202009113590641     9419       17          Silver    Volkswagen
# 210184   202010195186332   113250       16            Grey      Vauxhall
#
#        standard_model vehicle_condition  year_of_registration  price  \
# 332044         Sharan              USED                  2019  23000
# 173955        Qashqai              USED                  2019  16000
# 367464           Jazz              USED                  2008   4799
# 47695            Polo              USED                  2017  11000
# 210184       Insignia              USED                  2016   5400
#
#         body_type  crossover_car_and_van fuel_type
# 332044        MPV                  False    Diesel
# 173955        SUV                  False    Petrol
# 367464  Hatchback                  False    Petrol
# 47695   Hatchback                  False    Petrol
# 210184  Hatchback                  False    Diesel

# %%
# identify value types, and missing values
adverts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 402005 entries, 0 to 402004
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   public_reference       402005 non-null  int64
#  1   mileage                401878 non-null  float64
#  2   reg_code               370148 non-null  object
#  3   standard_colour        396627 non-null  object
#  4   standard_make          402005 non-null  object
#  5   standard_model         402005 non-null  object
#  6   vehicle_condition      402005 non-null  object
#  7   year_of_registration   368694 non-null  float64
#  8   price                  402005 non-null  int64
#  9   body_type              401168 non-null  object
#  10  crossover_car_and_van  402005 non-null  bool
#  11  fuel_type              401404 non-null  object
# dtypes: bool(1), float64(2), int64(2), object(7)
# memory usage: 34.1+ MB

# %%
adverts.describe().T
# Out:
#                       count            mean         std             min  \
# public_reference     402005 202007077472444 16916615997 201307177852187
# mileage              401878           37744       34832               0
# year_of_registration 368694            2015           8             999
# price                402005           17342       46437             120
#
#                                  25%             50%             75%  \
# public_reference     202009023197699 202009304400624 202010175124399
# mileage                        10481           28630           56876
# year_of_registration            2013            2016            2018
# price                           7495           12600           20000
#
#                                  max
# public_reference     202011025683478
# mileage                       999999
# year_of_registration            2020
# price                        9999999

# %%
# cleaning data
target = "price"

# removing public reference column as it has no influence on price
cleaned_ads = adverts.drop(columns=["public_reference"])
cleaned_ads.head(20)
# Out:
#     mileage reg_code standard_colour  standard_make        standard_model  \
# 0         0      NaN            Grey          Volvo                  XC90
# 1    108230       61            Blue         Jaguar                    XF
# 2      7800       17            Grey          SKODA                  Yeti
# 3     45000       16           Brown       Vauxhall                 Mokka
# 4     64000       64            Grey     Land Rover     Range Rover Sport
# 5     16000       17            Blue           Audi                    S5
# 6     24075       17             Red       Vauxhall                  Viva
# 7     99000       13          Bronze     Land Rover           Range Rover
# 8    111236       08           Black  Mercedes-Benz               S Class
# 9      9500       19           White     Land Rover           Range Rover
# 10    77000       60            Grey     Volkswagen                Passat
# 11    24487       17           Black        Peugeot                   208
# 12     4765       69           White          SKODA               Octavia
# 13    18214       19          Silver           SEAT                  Leon
# 14    31534       17            Grey           MINI                 Hatch
# 15    38603       16            Blue            BMW  2 Series Gran Tourer
# 16    52023       66            Blue     Volkswagen                  Golf
# 17        5      NaN             NaN         Nissan               X-Trail
# 18    29500       12            Grey  Mercedes-Benz               C Class
# 19        0      NaN           White     Volkswagen               T-Cross
#
#    vehicle_condition  year_of_registration  price    body_type  \
# 0                NEW                   NaN  73970          SUV
# 1               USED                  2011   7000       Saloon
# 2               USED                  2017  14000          SUV
# 3               USED                  2016   7995    Hatchback
# 4               USED                  2015  26995          SUV
# 5               USED                  2017  29000  Convertible
# 6               USED                  2017   5861    Hatchback
# 7               USED                  2013  24475          SUV
# 8               USED                  2008   6995    Limousine
# 9               USED                  2019  79995          SUV
# 10              USED                  2010   4499       Saloon
# 11              USED                  2017   8795    Hatchback
# 12              USED                  2019  16990       Estate
# 13              USED                  2019  14290    Hatchback
# 14              USED                  2017  19000    Hatchback
# 15              USED                  2016  16000          MPV
# 16              USED                  2016  13500       Estate
# 17               NEW                   NaN  27595          SUV
# 18              USED                  2012   9495       Saloon
# 19               NEW                   NaN  25000          SUV
#
#     crossover_car_and_van              fuel_type
# 0                   False  Petrol Plug-in Hybrid
# 1                   False                 Diesel
# 2                   False                 Petrol
# 3                   False                 Diesel
# 4                   False                 Diesel
# 5                   False                 Petrol
# 6                   False                 Petrol
# 7                   False                 Diesel
# 8                   False                 Diesel
# 9                   False                 Diesel
# 10                  False                 Diesel
# 11                  False                 Petrol
# 12                  False                 Petrol
# 13                  False                 Petrol
# 14                  False                 Petrol
# 15                  False                 Diesel
# 16                  False                 Diesel
# 17                  False                 Diesel
# 18                  False                 Petrol
# 19                  False                 Petrol

# %%
cleaned_ads.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 402005 entries, 0 to 402004
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   mileage                401878 non-null  float64
#  1   reg_code               370148 non-null  object
#  2   standard_colour        396627 non-null  object
#  3   standard_make          402005 non-null  object
#  4   standard_model         402005 non-null  object
#  5   vehicle_condition      402005 non-null  object
#  6   year_of_registration   368694 non-null  float64
#  7   price                  402005 non-null  int64
#  8   body_type              401168 non-null  object
#  9   crossover_car_and_van  402005 non-null  bool
#  10  fuel_type              401404 non-null  object
# dtypes: bool(1), float64(2), int64(1), object(7)
# memory usage: 31.1+ MB

# %%
cleaned_ads.describe().T
# Out:
#                       count  mean   std  min   25%   50%   75%     max
# mileage              401878 37744 34832    0 10481 28630 56876  999999
# year_of_registration 368694  2015     8  999  2013  2016  2018    2020
# price                402005 17342 46437  120  7495 12600 20000 9999999

# %%
X, y = cleaned_ads.drop(columns=[target]), cleaned_ads[target]

# %%
# segmenting features into their type
numeric_features = [
    "mileage",
    "year_of_registration"
]

categorical_features = [
    "reg_code",
    "standard_colour",
    "standard_make",
    "standard_model",
    "vehicle_condition",
    "body_type",
    "fuel_type"
]

boolean_features = [
    "crossover_car_and_van"
]

# double checking
print(f"Numeric: {numeric_features}")
print(f"Categorical: {categorical_features}")
print(f"Boolean: {boolean_features}")
# Out:
# Numeric: ['mileage', 'year_of_registration']
# Categorical: ['reg_code', 'standard_colour', 'standard_make', 'standard_model', 'vehicle_condition', 'body_type', 'fuel_type']
# Boolean: ['crossover_car_and_van']

# %%
# dealing with missing values

# replace missing numeric values with median, and scale for Nearest Neighbour and Linear Regression models.
numeric_transformer = Pipeline(steps=[
    ("imputer", SimpleImputer(strategy="median")),
    ("scaler", StandardScaler())
])

# replace missing categorical cells with unknown
categorical_transformer = Pipeline(steps=[
    ("imputer", SimpleImputer(strategy="constant", fill_value="Unknown")),
    ("onehot", OneHotEncoder(handle_unknown="ignore"))
])

# pass bool features as is because there are no missing values
preprocess = ColumnTransformer(
    transformers=[
        ("num", numeric_transformer, numeric_features),
        ("cat", categorical_transformer, categorical_features),
        ("bool", "passthrough", boolean_features),
    ],
    remainder="drop"
)

# %%
# checking that transformer is configured correctly
_ = preprocess.fit_transform(X.sample(1000, random_state=RANDOM_STATE))

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X,y,test_size=0.2, random_state=RANDOM_STATE
)

print(X_train.shape, X_test.shape)
print(y_train.shape, y_test.shape)
# Out:
# (321604, 10) (80401, 10)
# (321604,) (80401,)

# %%
# linear regression model
linreg = Pipeline(steps=[
    ("preprocess", preprocess),
    ("model", LinearRegression())
])

linreg.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocess',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['mileage',
#                                                    'year_of_registration']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(fill_value='Unknown',
#                                                                                  strategy='constant')),
#                                                                   ('onehot',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['reg_code',
#                                                    'standard_colour',
#                                                    'standard_make',
#                                                    'standard_model',
#                                                    'vehicle_condition',
#                                                    'body_type', 'fuel_type']),
#                                                  ('bool', 'passthrough',
#                                                   ['crossover_car_and_van'])])),
#                 ('model', LinearRegression())])

# %%
y_pred = linreg.predict(X_test)

mae = mean_absolute_error(y_test, y_pred)
rmse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"MAE:  {mae:,.0f}")
print(f"RMSE: {rmse:,.0f}")
print(f"R^2:  {r2:.3f}")
# Out:
# MAE:  3,986
# RMSE: 1,362,192,535
# R^2:  0.276

# %%
# log transforming price to deal with skewed pricing (new cars, luxury, etc.)
y_log = np.log1p(y)

X_train, X_test, y_train_log, y_test_log = train_test_split(
    X, y_log, test_size=0.2, random_state=RANDOM_STATE
)

# reducing the dataset due to high memory usage in KNN model
X_train_sub = X_train.sample(50000, random_state=RANDOM_STATE)
y_train_sub = y_train_log.loc[X_train_sub.index]

linreg_log = Pipeline(steps=[
    ("preprocess", preprocess),
    ("model", LinearRegression())
])

linreg_log.fit(X_train, y_train_log)
# Out:
# Pipeline(steps=[('preprocess',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['mileage',
#                                                    'year_of_registration']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(fill_value='Unknown',
#                                                                                  strategy='constant')),
#                                                                   ('onehot',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['reg_code',
#                                                    'standard_colour',
#                                                    'standard_make',
#                                                    'standard_model',
#                                                    'vehicle_condition',
#                                                    'body_type', 'fuel_type']),
#                                                  ('bool', 'passthrough',
#                                                   ['crossover_car_and_van'])])),
#                 ('model', LinearRegression())])

# %%
y_pred_log = linreg_log.predict(X_test)

# transforming price to actual values
y_pred = np.expm1(y_pred_log)
y_true = np.expm1(y_test_log)

# %%
mae = mean_absolute_error(y_true, y_pred)
mse = mean_squared_error(y_true, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_true, y_pred)

print(f"MAE (log model):  {mae:,.0f}")
print(f"RMSE (log model): {rmse:,.0f}")
print(f"R^2 (log model):  {r2:.3f}")
# Out:
# MAE (log model):  2,472
# RMSE (log model): 35,947
# R^2 (log model):  0.313

# %%
# K-Nearest-Neighbour

# using the same data - same imputations, encoding, and scaling.
knn = Pipeline(steps=[
    ("preprocess", preprocess),
    ("model", KNeighborsRegressor())
])

param_grid_knn = {
    "model__n_neighbors": [5, 7, 9],
    "model__weights": ["uniform", "distance"]
}

# %%
cv = KFold(n_splits=5, shuffle=True, random_state = RANDOM_STATE)

# %%
grid_knn = GridSearchCV(
    knn,
    param_grid_knn,
    scoring="neg_mean_absolute_error",
    cv=cv,
    n_jobs=-5
)

grid_knn.fit(X_train_sub, y_train_log)
# Out:
# GridSearchCV(cv=KFold(n_splits=5, random_state=42, shuffle=True),
#              estimator=Pipeline(steps=[('preprocess',
#                                         ColumnTransformer(transformers=[('num',
#                                                                          Pipeline(steps=[('imputer',
#                                                                                           SimpleImputer(strategy='median')),
#                                                                                          ('scaler',
#                                                                                           StandardScaler())]),
#                                                                          ['mileage',
#                                                                           'year_of_registration']),
#                                                                         ('cat',
#                                                                          Pipeline(steps=[('imputer',
#                                                                                           SimpleImputer(fill_value='Unknown',
#                                                                                                         strategy='co...
#                                                                                           OneHotEncoder(handle_unknown='ignore'))]),
#                                                                          ['reg_code',
#                                                                           'standard_colour',
#                                                                           'standard_make',
#                                                                           'standard_model',
#                                                                           'vehicle_condition',
#                                                                           'body_type',
#                                                                           'fuel_type']),
#                                                                         ('bool',
#                                                                          'passthrough',
#                                                                          ['crossover_car_and_van'])])),
#                                        ('model', KNeighborsRegressor())]),
#              n_jobs=3,
#              param_grid={'model__n_neighbors': [5, 7, 9],
#                          'model__weights': ['uniform', 'distance']},
#              scoring='neg_mean_absolute_error')

# %%
best_knn = grid_knn.best_estimator_

y_pred_log_knn = best_knn.predict(X_test)

y_pred_knn = np.expm1(y_pred_log_knn)
y_true = np.expm1(y_test_log)

mae_knn = mean_absolute_error(y_true, y_pred_knn)
rmse_knn = np.sqrt(mean_squared_error(y_true, y_pred_knn))
r2_knn = r2_score(y_true, y_pred_knn)

print(f"KNN MAE:  {mae_knn:,.0f}")
print(f"KNN RMSE: {rmse_knn:,.0f}")
print(f"KNN R^2:  {r2_knn:.3f}")
# Out:
# KNN MAE:  2,930
# KNN RMSE: 39,367
# KNN R^2:  0.176

# %%
# decision tree

tree = Pipeline(steps=[
    ("preprocess", preprocess),
    ("model", DecisionTreeRegressor(random_state=RANDOM_STATE))
])

param_grid_tree = {
    "model__max_depth": [10],
    "model__min_samples_leaf": [20],
    "model__min_samples_split":[15]
}

# %%
grid_tree = GridSearchCV(
    tree,
    param_grid_tree,
    scoring="neg_mean_absolute_error",
    cv=cv,
    n_jobs=3
)

grid_tree.fit(X_train, y_train_log)
# Out:
# GridSearchCV(cv=KFold(n_splits=5, random_state=None, shuffle=False),
#              estimator=Pipeline(steps=[('preprocess',
#                                         ColumnTransformer(transformers=[('num',
#                                                                          Pipeline(steps=[('imputer',
#                                                                                           SimpleImputer(strategy='median')),
#                                                                                          ('scaler',
#                                                                                           StandardScaler())]),
#                                                                          ['mileage',
#                                                                           'year_of_registration']),
#                                                                         ('cat',
#                                                                          Pipeline(steps=[('imputer',
#                                                                                           SimpleImputer(fill_value='Unknown',
#                                                                                                         strategy=...
#                                                                          ['reg_code',
#                                                                           'standard_colour',
#                                                                           'standard_make',
#                                                                           'standard_model',
#                                                                           'vehicle_condition',
#                                                                           'body_type',
#                                                                           'fuel_type']),
#                                                                         ('bool',
#                                                                          'passthrough',
#                                                                          ['crossover_car_and_van'])])),
#                                        ('model',
#                                         DecisionTreeRegressor(random_state=42))]),
#              n_jobs=3,
#              param_grid={'model__max_depth': [10],
#                          'model__min_samples_leaf': [20],
#                          'model__min_samples_split': [15]},
#              scoring='neg_mean_absolute_error')

# %%
# visualisation

plt.figure(figsize=(6,6))
plt.scatter(y_true, y_pred, alpha=0.2)
plt.plot([y_true.min(), y_true.max()],
        [y_true.min(),y_true.max()],
        linestyle="--"
        )
plt.xlabel("Actual Price (£)")
plt.ylabel("Predicted Price (£)")
plt.title("Linear Regression (log-transformed): Actual vs Predicted")
plt.show()

# %%
# outlier prices condense points in the graph, making it more difficult to see
max_price = 20000

plt.figure(figsize=(6,6))
plt.scatter(y_true, y_pred, alpha=0.2)
plt.plot([0, max_price], [0,max_price], linestyle="--")

plt.xlim(0,max_price)
plt.ylim(0,max_price)

plt.xlabel("Actual Price (£)")
plt.ylabel("Predicted Price (£)")
plt.title("Linear Regression (log-transformed): Actual vs Predicted (<=£20k)")
plt.show()

# %%
vis_idx = np.random.choice(len(y_true), size=1000, replace=False)

# %%
# reducing sample size to 2000 entries to better see trends

plt.figure(figsize=(6,6))
plt.scatter(y_true.iloc[vis_idx], y_pred[vis_idx], alpha=0.3)
plt.plot([0, max_price], [0, max_price], linestyle="--")

plt.xlim(0, max_price)
plt.ylim(0, max_price)

plt.xlabel("Actual Price (£)")
plt.ylabel("Predicted Price (£)")
plt.title("Linear Regression: Actual vs Predicted (2000 sample) (<=£20k)")
plt.show()

# %%
# visualisation of Nearest Neighbour model

plt.figure(figsize=(6,6))
plt.scatter(y_true.iloc[vis_idx], y_pred_knn[vis_idx], alpha=0.25)
plt.plot([0, max_price], [0, max_price], linestyle="--")

plt.xlim(0, max_price)
plt.ylim(0, max_price)

plt.xlabel("Actual Price (£)")
plt.ylabel("Predicted Price (£)")
plt.title("KNN Regression: Actual vs Predicted (2000 sample) (<=£20k)")
plt.show()

# %%
# visualisation of Decision Tree Regressor

plt.figure(figsize=(6,6))
plt.scatter(y_true.iloc[vis_idx], y_pred_tree[vis_idx], alpha=0.25)
plt.plot([0, max_price], [0, max_price], linestyle="--")

plt.xlim(0, max_price)
plt.ylim(0, max_price)

plt.xlabel("Actual Price (£)")
plt.ylabel("Predicted Price (£)")
plt.title("Decision Tree Regression: Actual vs Predicted (2000 sample) (<=£20k)")
plt.show()
